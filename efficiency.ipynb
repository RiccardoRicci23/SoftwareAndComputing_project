// %%
.L efficiency/efficiencyVSrun.cpp

// %%
efficiencyVSrun()
// Out:
// Looking for analysis.root files...
// 5 runs have been found! Find the outputs in ./efficiency/ folder.
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
