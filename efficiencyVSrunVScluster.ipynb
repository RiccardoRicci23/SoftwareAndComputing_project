// %%
.L efficiency/plotter_efficiencyVSrun.cpp

// %% [markdown]
// ## vs run number:

// %%
plotter_efficiencyVSrun()
// Out:
//  .csv file has been found! Check the output in ./efficiency/ folder.
// Info in <TCanvas::Print>: png file ./efficiency/TotalEfficiencyVSrun.png has been created

// %% [markdown]
// ## vs cluster:

// %%
.L efficiency/plotter_efficiencyVScluster.cpp

// %%
plotter_efficiencyVScluster()
// Out:
// Looking for .root files...
//  FCN=12389.9 FROM MIGRAD    STATUS=CONVERGED     311 CALLS         312 TOTAL
//                      EDM=3.17717e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     7.99299e+05   2.59867e+04   1.50528e+02   7.13463e-08
//    2  MPV          1.28429e+00   3.04494e-03   1.73912e-05  -1.29833e+00
//    3  Sigma        1.32181e-01   2.13304e-03   5.57479e-06   4.06283e+00
// 144398
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
// Info in <TCanvas::Print>: png file ./cluster/355234407.png has been created
//  FCN=18117.2 FROM MIGRAD    STATUS=CONVERGED     243 CALLS         244 TOTAL
//                      EDM=2.87349e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.6 per cent
//   EXT PARAMETER                                   STEP         FIRST
// ...
